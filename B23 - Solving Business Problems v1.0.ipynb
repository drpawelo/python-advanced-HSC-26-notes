# %% [markdown]
# There are no coding exercises for this badge, just the videos and 3 stars and a wish

# %% [markdown]
# ## ⭐️⭐️⭐️💥 What you learned in this session: Three stars and a wish
# **In you own words** write in your Learn diary:
#
# - 3 things you yould like to remember from this badge
# - 1 thing you wish to understand better in the future or a question you'd like to ask
