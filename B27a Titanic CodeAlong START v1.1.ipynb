# %% [markdown]
# # Titanic Codealong START
# Please note that you may be using a newer version of pandas than appears in the codealong video. Here are some small changes you can make to avoid error messages:
#
# **Old code**
# * `passengers.corr()`
# * `passengers.groupby(by="Pclass").mean(numeric_only = True)`
#
# **New code**: set numeric_only to True
# * `passengers.corr(numeric_only = True)`
# * `passengers.groupby(by="Pclass").mean(numeric_only = True)`

# %%
import pandas as pd

# %%
passengers = pd.read_csv('./data/titanic_kaggle_train.csv')
passengers
# https://www.kaggle.com/competitions/titanic/data
